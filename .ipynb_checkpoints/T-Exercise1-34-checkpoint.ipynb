# %%
from shapely import geometry
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/PreprocessedData1.csv' , sep=",")
df
# Out:
#        from_id    to_id      fromid_toid  route_number     at     from_x  \
# 0      5861326  5785640  5861326_5785640             1  08:10  24.970438
# 1      5861326  5785641  5861326_5785641             1  08:10  24.970438
# 2      5861326  5785642  5861326_5785642             1  08:10  24.970438
# 3      5861326  5785643  5861326_5785643             1  08:10  24.970438
# 4      5861326  5787544  5861326_5787544             1  08:10  24.970438
# ...        ...      ...              ...           ...    ...        ...
# 14639  5861326  5967092  5861326_5967092             1  08:06  24.970438
# 14640  5861326  5968733  5861326_5968733             1  08:06  24.970438
# 14641  5861326  5968734  5861326_5968734             1  08:06  24.970438
# 14642  5861326  5970374  5861326_5970374             1  08:06  24.970438
# 14643  5861326  5970374  5861326_5970374             1  08:06  24.970438
#
#           from_y       to_x       to_y  total_route_time  route_time  \
# ...

# %%
df.dtypes
# Out:
# from_id                int64
# to_id                  int64
# fromid_toid           object
# route_number           int64
# at                    object
# from_x               float64
# from_y               float64
# to_x                 float64
# to_y                 float64
# total_route_time     float64
# route_time           float64
# route_distance       float64
# route_total_lines    float64
# dtype: object

# %%
df.to_csv('data/PD1.csv',sep=",",header=None,index=False,float_format='%.2f')

# %%
df = pd.read_csv('data/Data.txt' , sep=" ",header=None)
df=pd.DataFrame(df)
df
# Out:
#                                                        0
# 0      from_id;to_id;fromid_toid;route_number;at;from...
# 1      5861326;5785640;5861326_5785640;1;08:10;24.970...
# 2      5861326;5785641;5861326_5785641;1;08:10;24.970...
# 3      5861326;5785642;5861326_5785642;1;08:10;24.970...
# 4      5861326;5785643;5861326_5785643;1;08:10;24.970...
# ...                                                  ...
# 14639  5861326;5967091;5861326_5967091;1;08:06;24.970...
# 14640  5861326;5967092;5861326_5967092;1;08:06;24.970...
# 14641  5861326;5968733;5861326_5968733;1;08:06;24.970...
# 14642  5861326;5968734;5861326_5968734;1;08:06;24.970...
# 14643  5861326;5970374;5861326_5970374;1;08:06;24.970...
#
# [14644 rows x 1 columns]

# %%
#df.iloc[0,0]
# Out:
# 'from_id;to_id;fromid_toid;route_number;at;from_x;from_y;to_x;to_y;total_route_time;route_time;route_distance;route_total_lines'

# %%
# Remove the trailing semicolon
header=df.iloc[0,0].rstrip(";")
# Split the string into a list of values
header=header.split(";")

# %%
# Create the temporary list containing all data without semicolon
# After this, data's shape''ll be 14643x13 (list dimension)
data=[] 
for i in range(df.shape[0]):#14644
    dataTmp=df.iloc[i,0].rstrip(";")
    dataTmp=dataTmp.split(";")
    data.append(dataTmp)

# %%
#Initial null dataframe
dfP=df = pd.DataFrame(np.nan, index=range(df.shape[0]), columns=data[0])
dfP
# Out:
#        from_id  to_id  fromid_toid  route_number  at  from_x  from_y  to_x  \
# 0          NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 1          NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 2          NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 3          NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 4          NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# ...        ...    ...          ...           ...  ..     ...     ...   ...
# 14639      NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 14640      NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 14641      NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 14642      NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
# 14643      NaN    NaN          NaN           NaN NaN     NaN     NaN   NaN
#
# ...

# %%
# Transfer the data
for idx_r in range(1,df.shape[0]):
    for idx_ls in range(np.shape(data)[1]):
        dfP.iloc[idx_r-1,idx_ls]=data[idx_r][idx_ls]

# %%
dfP
# Out:
#        from_id    to_id      fromid_toid route_number     at      from_x  \
# 0          NaN      NaN              NaN          NaN    NaN         NaN
# 1      5861326  5785640  5861326_5785640            1  08:10  24.9704379
# 2      5861326  5785641  5861326_5785641            1  08:10  24.9704379
# 3      5861326  5785642  5861326_5785642            1  08:10  24.9704379
# 4      5861326  5785643  5861326_5785643            1  08:10  24.9704379
# ...        ...      ...              ...          ...    ...         ...
# 14639  5861326  5967091  5861326_5967091            1  08:06  24.9704379
# 14640  5861326  5967092  5861326_5967092            1  08:06  24.9704379
# 14641  5861326  5968733  5861326_5968733            1  08:06  24.9704379
# 14642  5861326  5968734  5861326_5968734            1  08:06  24.9704379
# 14643  5861326  5970374  5861326_5970374            1  08:06  24.9704379
#
#            from_y                to_x                to_y total_route_time  \
# ...

# %%
for idx_r in range(1,df.shape[0]):
    for idx_ls in range(np.shape(data)[1]):
        dfP.iloc[idx_r-1,idx_ls]=data[idx_r][idx_ls]

# %%
dfP
# Out:
#        from_id    to_id      fromid_toid route_number     at      from_x  \
# 0      5861326  5785640  5861326_5785640            1  08:10  24.9704379
# 1      5861326  5785641  5861326_5785641            1  08:10  24.9704379
# 2      5861326  5785642  5861326_5785642            1  08:10  24.9704379
# 3      5861326  5785643  5861326_5785643            1  08:10  24.9704379
# 4      5861326  5787544  5861326_5787544            1  08:10  24.9704379
# ...        ...      ...              ...          ...    ...         ...
# 14639  5861326  5967092  5861326_5967092            1  08:06  24.9704379
# 14640  5861326  5968733  5861326_5968733            1  08:06  24.9704379
# 14641  5861326  5968734  5861326_5968734            1  08:06  24.9704379
# 14642  5861326  5970374  5861326_5970374            1  08:06  24.9704379
# 14643  5861326  5970374  5861326_5970374            1  08:06  24.9704379
#
#            from_y                to_x                to_y total_route_time  \
# ...

# %%
dfP.to_csv('data/PreprocessedData1.csv',encoding='utf-8',index=False,float_format='%.2f',)#sep=' '

# %%
df = pd.DataFrame({
    'col1': ['A', 'A', 'B', np.nan, 'D', 'C'],
    'col2': [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3],
    'col4': ['a', 'B', 'c', 'D', 'e', 'F']
})
df
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 3  NaN     8     4    D
# 4    D     7     2    e
# 5    C     4     3    F

# %%
df.sort_values(by=['col1'])
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 5    C     4     3    F
# 4    D     7     2    e
# 3  NaN     8     4    D
